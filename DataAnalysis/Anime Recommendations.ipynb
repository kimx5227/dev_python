# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
anime_df = pd.read_csv('anime.csv')
ratings_df = pd.read_csv('rating.csv')

# %%
anime_df
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
ratings_df
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
import collections
genres_dict = collections.defaultdict(int)
for genre in anime_df['genre']:
    if str(genre) == 'nan':
        continue
    split = genre.split(', ')
    for item in genre_list:
        genres_dict[item] += 1
genres = {k: v for k, v in sorted(genres.items(), key=lambda item: item[1], reverse=True)}
genres
# Out:
# {'Comedy': 4645,
#  'Action': 2845,
#  'Adventure': 2348,
#  'Fantasy': 2309,
#  'Sci-Fi': 2070,
#  'Drama': 2016,
#  'Shounen': 1712,
#  'Kids': 1609,
#  'Romance': 1464,
#  'School': 1220,
#  'Slice of Life': 1220,
#  'Hentai': 1141,
#  'Supernatural': 1037,
#  'Mecha': 944,
#  'Music': 860,
#  'Historical': 806,
#  'Magic': 778,
#  'Ecchi': 637,
#  'Shoujo': 603,
#  'Seinen': 547,
#  'Sports': 543,
#  'Mystery': 495,
#  'Super Power': 465,
#  'Military': 426,
#  'Parody': 408,
#  'Space': 381,
#  'Horror': 369,
#  'Harem': 317,
#  'Demons': 294,
#  'Martial Arts': 265,
#  'Dementia': 240,
#  'Psychological': 229,
#  'Police': 197,
#  'Game': 181,
#  'Samurai': 148,
#  'Vampire': 102,
#  'Thriller': 87,
#  'Cars': 72,
#  'Shounen Ai': 65,
#  'Shoujo Ai': 55,
#  'Josei': 54,
#  'Yuri': 42,
#  'Yaoi': 39}

# %%
episodes_dict = collections.defaultdict(int)
ova_episodes = collections.defaultdict(int)
tv_episodes = collections.defaultdict(int)
movie_episodes = collections.defaultdict(int)
anime_df.loc[anime_df['episodes'] == 'Unknown'] = "Ongoing"
for index, num_episodes in enumerate(anime_df["episodes"]):
    episodes_dict[num_episodes] += 1
    if anime_df.loc[index,'type'] == 'TV':
        tv_episodes[num_episodes] += 1
    elif anime_df.loc[index,'type'] == 'Movie':
        movie_episodes[num_episodes] += 1
    else:
        ova_episodes[num_episodes] += 1
episodes_dict = {k: v for k, v in sorted(episodes_dict.items(), key=lambda item: item[1], reverse=True)}
ova_episodes = {k: v for k, v in sorted(ova_episodes.items(), key=lambda item: item[1], reverse=True)}
tv_episodes = {k: v for k, v in sorted(tv_episodes.items(), key=lambda item: item[1], reverse=True)}
movie_episodes = {k: v for k, v in sorted(movie_episodes.items(), key=lambda item: item[1], reverse=True)}
episodes_dict
# Out:
# {'1': 2311,
#  '2': 8,
#  '3': 7,
#  '12': 4,
#  '5': 3,
#  '6': 3,
#  '7': 2,
#  '4': 2,
#  '9': 1,
#  '100': 1,
#  '14': 1,
#  '10': 1}

# %%
movie_episodes
# Out:
# {'1': 2311,
#  '2': 8,
#  '3': 7,
#  '12': 4,
#  '5': 3,
#  '6': 3,
#  '7': 2,
#  '4': 2,
#  '9': 1,
#  '100': 1,
#  '14': 1,
#  '10': 1}

# %%
ova_episodes
# Out:
# {'1': 3366,
#  '2': 1067,
#  '3': 490,
#  'Ongoing': 340,
#  '4': 307,
#  '6': 243,
#  '5': 104,
#  '7': 67,
#  '12': 65,
#  '13': 54,
#  '10': 51,
#  '8': 46,
#  '9': 32,
#  '26': 17,
#  '11': 17,
#  '14': 14,
#  '24': 14,
#  '15': 11,
#  '20': 10,
#  '16': 10,
#  '25': 6,
#  '18': 5,
#  '51': 3,
#  '78': 3,
#  '52': 2,
#  '35': 2,
#  '22': 2,
#  '39': 2,
#  '41': 2,
#  '17': 2,
#  '110': 1,
#  '28': 1,
#  '48': 1,
#  '74': 1,
#  '64': 1,
#  '27': 1,
#  '32': 1,
#  '46': 1,
#  '60': 1,
#  '40': 1,
#  '33': 1,
#  '54': 1,
#  '84': 1,
#  '29': 1,
#  '30': 1,
#  '53': 1,
#  '63': 1,
#  '38': 1}

# %%
tv_episodes
# Out:
# {'12': 747,
#  '13': 518,
#  '26': 497,
#  '52': 175,
#  '24': 167,
#  '25': 159,
#  '51': 100,
#  '39': 84,
#  '50': 83,
#  '10': 62,
#  '11': 55,
#  '22': 40,
#  '48': 34,
#  '23': 33,
#  '49': 31,
#  '20': 26,
#  '47': 25,
#  '38': 22,
#  '6': 22,
#  '30': 21,
#  '16': 20,
#  '43': 18,
#  '40': 18,
#  '4': 18,
#  '46': 18,
#  '14': 17,
#  '45': 15,
#  '21': 15,
#  '35': 15,
#  '27': 14,
#  '37': 14,
#  '5': 14,
#  '8': 14,
#  '44': 13,
#  '104': 12,
#  '36': 11,
#  '34': 11,
#  '65': 11,
#  '33': 10,
#  '15': 10,
#  '31': 10,
#  '29': 10,
#  '56': 10,
#  '61': 9,
#  '54': 9,
#  '42': 9,
#  '32': 9,
#  '100': 9,
#  '78': 8,
#  '53': 8,
#  '3': 8,
#  '64': 7,
#  '77': 7,
#  '60': 7,
#  '73': 7,
#  '9': 7,
#  '130': 7,
#  '156': 7,
#  '75': 6,
#  '41': 6,
#  '18': 6,
#  '28': 6,
#  '74': 5,
#  '101': 5,
#  '102': 5,
#  '103': 5,
#  '96': 4,
#  '70': 4,
#  '63': 4,
#  '19': 4,
#  '58': 4,
#  '59': 4,
#  '94': 3,
#  '114': 3,
#  '109': 3,
#  '97': 3,
#  '17': 3,
#  '127': 3,
# ...
